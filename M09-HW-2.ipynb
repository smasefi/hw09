# %% [markdown]
# # Metadata
#
# ```yaml
# Course:  DS 5100
# Module:  09 Python Packages
# Topic:   HW Package Booklover
# Author:  R.C. Alvarado (adapted)
# Date:    2 July 2024 (revised)
# ```

# %% [markdown]
# # Student Info
#
# * Name:
# * Net UD:
# * URL of this file in GitHub:

# %% [markdown]
# # Instructions
#
# In your **private course repo on Rivanna**, use this Jupyter notebook and the data file described to write code that performs the tasks below.
#
# Save your notebook in the `M09` directory.
#
# Remember to add and commit these files to your repo.
#
# Then push your commits to your repo on GitHib.
#
# Be sure to fill out the **Student Info** block above.
#
# To submit your homework, save your results as a PDF and upload it to GradeScope. More information about how to create the PDF for this assignment are included at the end of this document.
#
# **TOTAL POINTS: 8**

# %% [markdown]
# # Overview
#
# Follow the following recipe we used in class to package the code you wrote for `HW08` -- `booklover.py` and `booklover_test.py`.
#
# * Create a new git repo for your package.
# * Create and edit the required files and directories for your package and move the booklover modules there.
#   * <span style="color:green;font-weight:bold;">Create a package directory called `booklover`.</span>
#   * <span style="color:green;font-weight:bold;">Create a module called `booklover` inside the package directory.</span>
#   * <span style="color:green;font-weight:bold;">Put the test file above the package directory, in the root of the project directory.</span>
# * Stage, commit, and push all the files you've created.
# * Install your package with pip.
# * Outside of your package dir, write a script to test your method.
#
# Put this notebook in your repo. This will allow you to execute bash commands and capture the outpunt directly in the notebook.
#
# **TOTAL: 8 POINTS**

# %% [markdown]
# # Tasks

# %% [markdown]
# ## Task 1
#
# (5 points)
#
# Show the directory structure of your repo by running this command from the root of your repo.
#
# <span style="color:green;font-weight:bold;">Note: You may run this from the command line and cut-and-paste a screenshot of your results here.</span>

# %%
# !ls -lR
# Out:
# .:
# total 10
# drwx--S--- 3 sma9am users 4096 Mar 23 13:53 booklover
# -rw------- 1 sma9am users 3026 Mar 23 13:52 booklover_test.py
# -rw------- 1 sma9am users 1071 Mar 23 12:19 LICENSE
# -rw------- 1 sma9am users 6772 Mar 23 13:56 M09-HW-2.ipynb
# -rw------- 1 sma9am users    6 Mar 23 12:19 README.md
#
# ./booklover:
# total 1
# -rw------- 1 sma9am users 998 Mar 23 13:53 booklover.py
# -rw------- 1 sma9am users   0 Mar 23 13:51 __init__.py

# %% [markdown]
# ![Screenshot 2025-03-23 at 2.36.40 PM.png](attachment:76c2f886-57f9-42d2-b126-d2a9ae9d4326.png)

# %% [markdown]
# ## Task 2
#
# (1 point)
#
# Put the URL of your GitHub repo here. Just paste it into a Markdown cell.

# %% [markdown]
# URL: https://github.com/smasefi/hw09#

# %% [markdown]
# ## Task 3
#
# (1 point)
#
# Show the results of installing your package.
#
# ```bash
# !pip install -e .
# ```
#
# <span style="color:green;font-weight:bold;">Note: You may run this from the command line and cut-and-paste a screenshot of your results here.</span>

# %% [markdown]
# ![Screenshot 2025-03-23 at 2.21.38 PM.png](attachment:ea9e2a48-dbf4-4193-b9fa-5c0239e5abeb.png)

# %% [markdown]
# ## Task 4
#
# (1 point)
#
# Create a file outside your repo to test your package by running it.
#
# To do this, import the package into your file and create a BookLover object.
#
# Then add a book and then print number books read.
#
# Then run the file.
#
# Show the output of running the file below, using a command like the following:
#
# ```bash
# !python ../book_lover_demo.py
# ```
#
# <span style="color:green;font-weight:bold;">Note: You may run this from the command line and cut-and-paste a screenshot of your results here.</span>

# %% [markdown]
# ![Screenshot 2025-03-23 at 5.29.02 PM.png](attachment:58bc8fcb-cd2a-4be0-bd21-579313cc05be.png)
